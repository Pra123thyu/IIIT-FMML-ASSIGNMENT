# %% [markdown]
# <a href="https://colab.research.google.com/github/Pra123thyu/IIIT-FMML-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 05:54:49--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   139MB/s    in 0.5s
#
# 2024-03-26 05:54:50 (139 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2227   1709.03683v1  Randomized experiments have been critical tool...    cs
# 9899   1502.06132v1  We propose a self-organizing memory architectu...    cs
# 19068   1301.7418v1  In the real world, insufficient information, l...    cs
# 6859   1706.09367v1  Machine Learning (ML) has been successfully ap...  stat
# 11900  1703.07625v1  This paper describes a method for clustering d...    cs
# ...             ...                                                ...   ...
# 6342   1611.05181v3  Graphs are fundamental mathematical structures...    cs
# 7774   1803.02922v2  Modern supervised learning techniques, particu...  stat
# 7375   1712.02330v1  The Generative Adversarial Networks (GANs) hav...  stat
# 30684  1801.00256v2  Saliency map detection, as a method for detect...    cs
# 32241   1401.0044v1  When belief propagation (BP) converges, it doe...    cs
#
#                                                    title  year  \
# 2227   A Practically Competitive and Provably Consist...  2017
# 9899   Universal Memory Architectures for Autonomous ...  2015
# 19068  Flexible and Approximate Computation through S...  2013
# 6859   autoBagging: Learning to Rank Bagging Workflow...  2017
# 11900  Clustering for Different Scales of Measurement...  2017
# ...                                                  ...   ...
# 6342   Graph Learning from Data under Structural and ...  2016
# 7774   Fast Convergence for Stochastic and Distribute...  2018
# 7375   SGAN: An Alternative Training of Generative Ad...  2017
# 30684  Context aware saliency map generation using se...  2017
# 32241         Approximating the Bethe partition function  2013
#
#                                                 keywords
# 2227   [randomized, experiments, significant, heterog...
# 9899   [organizing, architecture, perceptual, experie...
# 19068  [insufficient, information, computation, resou...
# 6859   [successfully, applications, techniques, succe...
# 11900  [describes, clustering, dimensions, different,...
# ...                                                  ...
# 6342   [fundamental, mathematical, structures, repres...
# 7774   [supervised, techniques, particularly, dimensi...
# 7375   [generative, adversarial, demonstrated, impres...
# 30684  [detection, detecting, important, applications...
# 32241  [propagation, converges, stationary, strikingl...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2227     [randomized, experiments, significant, heterog...
# 9899     [organizing, architecture, perceptual, experie...
# 19068    [insufficient, information, computation, resou...
# 6859     [successfully, applications, techniques, succe...
# 11900    [describes, clustering, dimensions, different,...
#                                ...
# 36493    [computational, distributed, computing, geogra...
# 6890     [gaussians, streaming, dimensions, generated, ...
# 18401    [technique, suggested, specially, developed, r...
# 13047    [clustering, multidimensional, statistical, pr...
# 33026    [optimality, nesterovs, smoothing, technique, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bf21f69-a9da-4810-b54b-729f8fc449bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bf21f69-a9da-4810-b54b-729f8fc449bd")) {                    Plotly.newPlot(                        "5bf21f69-a9da-4810-b54b-729f8fc449bd",                        [{"x":["properties","applications","customize","assignment","randomized","significant","literature","therefore","algorithm","treatment","practically","generated","synthetic","parameter","competitive","population","algorithms","consistent","constructing","treatments","experiments","theoretical","regularity","correctly","heterogeneity","promising","important","conditions","characteristics","experience","quadratic","structure","representation","representations","architecture","recovering","principle","supporting","complexity","learnable","precision","effectively","information","requirements","relations","positively","environment","equivalence","universal","convexity","underlies","organizing","application","available","complexes","sufficiently","arbitrary","autonomous","architectures","perceptual","successively","approximate","efficient","quantitative","satisfactory","effective","reduction","approaches","insufficient","heuristic","resources","solutions","computation","continuously","maximized","structural","completely","structures","computations","inaccurate","different","successful","successfully","typically","reproducibility","optimization","automated","characterization","systematically","exploiting","techniques","classification","statistically","libraries","automatically","replacement","performance","workflows","generalizability","proportional","respectively","unsupervised","consisting","dimension","combination","associated","clustering","uncontrolled","dimensions","describes","consecutive","weighting","measurement","implement","developed","supervisory","convolutional","enumerating","displayed","recognition","generalize","principled","remarkable","attributed","specifically","categories","dramatically","activations","generalizes","performed","organized","configurations","recurrent","improvements","dynamically","contextual","combining","variation","vocabulary","frequency","experimental","increased","verification","maintenance","extracting","obtaining","resulting","development","monitored","validated","proliferation","discovered","identifying","generation","extraction","attention","improvement","currently","supervision","extractors","regarding","indicated","aggregate","investigate","representing","otherwise","hypothesis","asymptotic","deviation","hoeffding","constraint","probability","characterize","convergence","criterion","asymptotically","statistical","discrepancy","exponential","nonparametric","computationally","optimality","functions","considered","likelihood","demonstrate","corresponds","minimizing","outperforms","reinforcement","minimization","translation","objective","gradients","divergence","estimator","additional","providing","assumptions","constraints"],"y":[212,451,3,37,28,267,132,154,796,32,12,173,134,132,112,45,572,90,43,3,592,161,14,35,6,130,354,127,101,29,28,318,348,231,214,24,61,22,232,12,87,104,703,57,99,6,109,28,31,11,2,15,251,329,7,23,86,50,115,24,4,129,395,61,19,236,101,438,12,53,64,143,146,10,3,78,39,109,34,13,756,70,94,109,8,303,98,24,14,71,393,555,23,6,196,6,875,1,7,18,92,142,54,64,144,95,152,1,54,92,12,17,28,74,188,5,377,1,6,379,44,22,30,13,171,71,22,29,21,115,23,28,142,121,40,51,118,60,39,60,381,36,43,8,71,32,166,127,4,46,7,25,72,134,142,171,142,53,57,8,47,9,20,172,71,20,52,23,15,2,101,180,51,106,38,13,179,12,37,17,91,22,183,128,81,563,18,49,242,113,54,107,174,28,30,26,114,84,63,114],"type":"bar"},{"x":["properties","applications","customize","assignmen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dipole</span> <span style=''>Vectors</span> <span style=''>in</span> <span style=''>Images</span> <span style='background-color:rgba(0, 255, 0, 0.429305912596401);'>Processing</span> <br/><br/><span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluating</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>field</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>brightness</span> <span style=''>map</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>dipole</span> <span style=''>vectors</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>adapting</span> <span style=''>to</span> <span style=''>the</span> <span style=''>image</span> <span style=''>gray</span> <span style=''>tone</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dipole</span> <span style=''>moment</span> <span style=''>of</span> <span style=''>charge</span> <span style='background-color:rgba(255, 0, 0, 0.3548387096774193);'>distributions</span> <span style=''>We</span> <span style=''>will</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>the</span> <span style=''>dipoles</span> <span style=''>and</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>field</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>field</span> <span style=''>in</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.6301075268817204);'>recognition</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>mixture</span> <span style=''>(DPM)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ubiquitous</span> <span style=''>flexible</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>model</span> <span style=''>However</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>this</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>so</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style=''>are</span> <span style=''>required</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>DPM</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>and</span> <span style=''>time</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>plentiful</span> <span style=''>For</span> <span style=''>example</span> <span style=''>they</span> <span style=''>would</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>for</span> <span style=''>digital</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>on</span> <span style=''>embedded</span> <span style=''>hardware</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>are</span> <span style=''>at</span> <span style=''>a</span> <span style=''>serious</span> <span style=''>premium</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplified</span> <span style=''>yet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style=''>rigorous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>maximum</span> <span style=''>a</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fighting</span> <span style=''>Bandits</span> <span style=''>with</span> <span style=''>a</span> <span style=''>New</span> <span style=''>Kind</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Smoothness</span> <br/><br/><span style=''>We</span> <span style=''>define</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>based</span> <span style=''>on</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>two</span> <span style=''>main</span> <span style=''>results</span> <span style=''>First</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3025210084033614);'>regularization</span> <span style=''>via</span> <span style=''>the</span> <span style=''>emphTsallis</span> <span style=''>entropy</span> <span style=''>which</span> <span style=''>includes</span> <span style=''>EXP3</span> <span style=''>as</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>Theta(sqrtTN)</span> <span style=''>minimax</span> <span style=''>regret</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbation</span> <span style=''>methods</span> <span style=''>achieve</span> <span style=''>a</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>regret</span> <span style=''>as</span> <span style=''>low</span> <span style=''>as</span> <span style=''>O(sqrtTN</span> <span style=''>log</span> <span style=''>N)</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>has</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>hazard</span> <span style=''>rate</span> <span style=''>For</span> <span style=''>example</span> <span style=''>the</span> <span style=''>Gumbel</span> <span style=''>Weibull</span> <span style=''>Frechet</span> <span style=''>Pareto</span> <span style=''>and</span> <span style=''>Gamma</span> <span style='background-color:rgba(255, 0, 0, 0.3548387096774193);'>distributions</span> <span style=''>all</span> <span style=''>satisfy</span> <span style=''>this</span> <span style=''>key</span> <span style=''>property</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Detecting</span> <span style=''>early</span> <span style=''>signs</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depressive</span> <span style=''>and</span> <span style=''>manic</span> <span style=''>episodes</span> <span style=''>in</span> <span style=''>patients</span> <span style=''>with</span> <span style=''>bipolar</span> <span style=''>disorder</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signature</span> <span style=''>based</span> <span style=''>model</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>major</span> <span style=''>mood</span> <span style=''>episodes</span> <span style=''>and</span> <span style=''>subsyndromal</span> <span style=''>mood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instability</span> <span style=''>cause</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disability</span> <span style=''>in</span> <span style=''>patients</span> <span style=''>with</span> <span style=''>bipolar</span> <span style=''>disorder</span> <span style=''>Early</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>mood</span> <span style=''>episodes</span> <span style=''>enabling</span> <span style=''>timely</span> <span style=''>mood</span> <span style=''>stabilisation</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>clinical</span> <span style=''>goal</span> <span style=''>Recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technological</span> <span style=''>advances</span> <span style=''>allow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prospective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <span style=''>of</span> <span style=''>mood</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>enabling</span> <span style=''>more</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>data</span> <span style=''>capture</span> <span style=''>The</span> <span style=''>complex</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>these</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style=''>deriving</span> <span style=''>meaning</span> <span style=''>from</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>mean</span> <span style=''>pose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>analytic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signature</span> <span style=''>method</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>has</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>ordered</span> <span style=''>time</span> <span style=''>series</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07623797648735305)
# 	processing (0.09903811898824368)
# 	knowledge (0.1282508015675098)
# 	experimental (0.13573209832561453)
# 	information (0.2504453152832205)
# 	segmentation (0.07623797648735305)
# 	detection (0.12682579266120414)
# 	different (0.26932668329177056)
# 	convolutional (0.13430708941930888)
# 	recognition (0.1350195938724617)
#
# Some Statistics words are:
# 	stochastic (0.13146011038635222)
# 	theoretical (0.14500752634219768)
# 	estimation (0.17511289513296538)
# 	algorithm (0.3738083291520321)
# 	variables (0.14099347717009533)
# 	statistical (0.15955845459106874)
# 	dimensional (0.18665328650275967)
# 	distribution (0.19518314099347717)
# 	inference (0.19819367787255393)
# 	regression (0.17862518815855494)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52791de0-f8f5-4b95-ba47-6a027ebbbb37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52791de0-f8f5-4b95-ba47-6a027ebbbb37")) {                    Plotly.newPlot(                        "52791de0-f8f5-4b95-ba47-6a027ebbbb37",                        [{"x":["properties","applications","customize","assignment","randomized","significant","literature","therefore","algorithm","treatment","practically","generated","synthetic","parameter","competitive","population","algorithms","consistent","constructing","treatments","experiments","theoretical","regularity","correctly","heterogeneity","promising","important","conditions","characteristics","experience","quadratic","structure","representation","representations","architecture","recovering","principle","supporting","complexity","learnable","precision","effectively","information","requirements","relations","positively","environment","equivalence","universal","convexity","underlies","organizing","application","available","complexes","sufficiently","arbitrary","autonomous","architectures","perceptual","successively","approximate","efficient","quantitative","satisfactory","effective","reduction","approaches","insufficient","heuristic","resources","solutions","computation","continuously","maximized","structural","completely","structures","computations","inaccurate","different","successful","successfully","typically","reproducibility","optimization","automated","characterization","systematically","exploiting","techniques","classification","statistically","libraries","automatically","replacement","performance","workflows","generalizability","proportional","respectively","unsupervised","consisting","dimension","combination","associated","clustering","uncontrolled","dimensions","describes","consecutive","weighting","measurement","implement","developed","supervisory","convolutional","enumerating","displayed","recognition","generalize","principled","remarkable","attributed","specifically","categories","dramatically","activations","generalizes","performed","organized","configurations","recurrent","improvements","dynamically","contextual","combining","variation","vocabulary","frequency","experimental","increased","verification","maintenance","extracting","obtaining","resulting","development","monitored","validated","proliferation","discovered","identifying","generation","extraction","attention","improvement","currently","supervision","extractors","regarding","indicated","aggregate","investigate","representing","otherwise","hypothesis","asymptotic","deviation","hoeffding","constraint","probability","characterize","convergence","criterion","asymptotically","statistical","discrepancy","exponential","nonparametric","computationally","optimality","functions","considered","likelihood","demonstrate","corresponds","minimizing","outperforms","reinforcement","minimization","translation","objective","gradients","divergence","estimator","additional","providing","assumptions","constraints","including","mechanism","polynomial","objectives","minimized","estimators","contribute","incentives","regression","framework","estimation","strategic","interrelated","exponentially","sensitive","normalization","expressive","summarized","trajectory","expressivity","dimensional","regularizing","alternative","encountered","segmented","inference","scheduling","increasing","distributed","operations","partitioning","empirically","processor","incorporates","estimated","parameters","demonstrating","limitations","orthogonal","partially","independent","orthogonality","perturbations","construct","equations","insensitive","procedure","robustness","estimates","requirement","employing","recognizer","segmentation","classifier","introd ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	irreducible
# 	parametrically
# 	purchases
# 	cumulants
# 	perturbative
# 	conditionals
# 	physiologic
# 	frontiers
# 	exponents
# 	chemicals
# 	distributionally
# 	presumably
# 	subpopulations
# 	bootstrapped
# 	inexactly
# 	sociology
# 	groupings
# 	quadrature
# 	supernova
# 	subsamples
# Some words which never appear in Statistics papers:
# 	proliferation
# 	processor
# 	recognizer
# 	surpassed
# 	adjective
# 	facilities
# 	versioning
# 	enriching
# 	imitating
# 	compilation
# 	terminological
# 	summarises
# 	annotating
# 	bilingual
# 	monolingual
# 	illumination
# 	daubechies
# 	verifiable
# 	collocations
# 	attribution

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0638193572106986e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
